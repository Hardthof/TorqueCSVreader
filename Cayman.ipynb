# %%
import os
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import datetime
import time

timeResolutionFactor = 1000                      

def createScatters(plot, x):
    return [go.Scattergl(x = x, y = plot)]

def addScatter(fig, scatters, row, col):
    for scat in scatters:
            fig.add_trace(scat, row=row, col=col)
            
def plotList(list, df):
    rows = len(data)

    titles = ("Gps Speed")
    fig = make_subplots(rows = rows, cols = 1, shared_xaxes=True)

    x = df['time'] - df['time'][0]
    x = x / timeResolutionFactor

    coln = 1
    for rown, title in enumerate(data, 1):
        addScatter(fig, createScatters(df[title], x), rown, coln)
        fig.update_yaxes(title_text = title, row=rown, col=coln)



    fig.update_layout(height = 1200, showlegend = False)
    fig.update_xaxes(title_text = 'Time(s)', row=rown, col=coln)
    fig.show()

# %%
# Anfahruckeln

file = r"Tempomat80.csv"
#file = r"VollastAutobahn.csv"
#file = r"Gp3.csv"


df = pd.read_csv(file, sep=',')

df['FT - Bank1'] = df['STFT - Bank1'] + df['LTFT - Bank1']
df['FT - Bank2'] = df['STFT - Bank2'] + df['LTFT - Bank2']
df['Timing advance'] = df['Timing advance'] / 10


#print(os.getcwd())
#print(df.head)
#list(df)

'''
data = [ #'session', \
         #'time', \
         #'GPS Longitude', \
         #'GPS Latitude', \
         #'GPS Bearing', \
         #'Absolute throttle position B', \
         #'Throttle position', \
         #'Fuel Rail Pressure', \
         #'MAF(air flow)', \
         #'Catalyst Temp - Bank 1  Sensor 1', \
         #'Catalyst Temp - Bank 2  Sensor 1', \
         #'STFT - Bank1', \
         #'LTFT - Bank1', \
         #'FT - Bank1', \
         #'STFT - Bank2', \
         #'LTFT - Bank2', \
         #'FT - Bank2', \
         #'Air Fuel Ratio (alt)', \
         #'Air Fuel Ratio', \
         #'Coolant', \
         #'Engine Load', \
         #'Absolute load value', \
         #'O2 S1 Equiv. Ratio and/or Current', \
         #'O2 Sensor 1x2', \
         #'O2 Sensor 2x2', \
         #'Relative throttle position', \
         #'RPM', \
         #'Timing advance', \
         #'GPS Speed']
    
data = [ 'session', \
         'time', \
         'GPS Longitude', \
         'GPS Latitude', \
         'GPS Bearing', \
         'Absolute throttle position B', \
         'Throttle position', \
         'Fuel Rail Pressure', \
         'MAF(air flow)', \
         'Catalyst Temp - Bank 1  Sensor 1', \
         'Catalyst Temp - Bank 2  Sensor 1', \
         'STFT - Bank1', \
         'LTFT - Bank1', \
         'FT - Bank1', \
         'STFT - Bank2', \
         'LTFT - Bank2', \
         'FT - Bank2', \
         'Air Fuel Ratio (alt)', \
         'Air Fuel Ratio', \
         'Coolant', \
         'Engine Load', \
         'Absolute load value', \
         'O2 S1 Equiv. Ratio and/or Current', \
         'O2 Sensor 1x2', \
         'O2 Sensor 2x2', \
         'Relative throttle position', \
         'RPM', \
         'Timing advance', \
         'GPS Speed']
'''

data = [ #'session', \
         #'time', \
         #'GPS Longitude', \
         #'GPS Latitude', \
         #'GPS Bearing', \
         'Absolute throttle position B', \
         'Throttle position', \
         #'Fuel Rail Pressure', \
         'MAF(air flow)', \
         #'Catalyst Temp - Bank 1  Sensor 1', \
         #'Catalyst Temp - Bank 2  Sensor 1', \
         #'STFT - Bank1', \
         #'LTFT - Bank1', \
         #'FT - Bank1', \
         #'STFT - Bank2', \
         #'LTFT - Bank2', \
         #'FT - Bank2', \
         #'Air Fuel Ratio (alt)', \
         #'Air Fuel Ratio', \
         #'Coolant', \
         'Engine Load', \
         'Absolute load value', \
         #'O2 S1 Equiv. Ratio and/or Current', \
         #'O2 Sensor 1x2', \
         #'O2 Sensor 2x2', \
         'Relative throttle position', \
         'RPM', \
         'Timing advance', \
         #'GPS Speed' \
         ]

plotList(data, df)
# Out:
# <div>                            <div id="a5c945a7-c41f-405d-b403-f80f3fc1bbda" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5c945a7-c41f-405d-b403-f80f3fc1bbda")) {                    Plotly.newPlot(                        "a5c945a7-c41f-405d-b403-f80f3fc1bbda",                        [{"type": "scattergl", "x": [0.0, 0.994, 1.994, 2.995, 3.994, 4.994, 5.994, 6.995, 7.994, 8.995, 9.994, 10.995, 11.994, 12.995, 13.994, 14.994, 15.994, 16.994, 17.994, 18.994, 19.994, 20.995, 21.994, 22.994, 23.995, 24.994, 25.994, 26.994, 27.994, 28.995, 29.994, 30.994, 31.995, 32.994, 33.994, 34.994, 35.994, 36.995, 37.994, 39.994, 40.994, 42.994, 43.995, 45.995, 46.994, 47.994, 49.994, 50.994, 52.994, 53.995, 54.994, 55.994, 56.994, 57.994, 58.994, 59.994, 60.
# ...

# %%
# Fuel Trim 80kmh

#file = r"Tempomat80.csv"
file = r"VollastAutobahn.csv"
#file = r"Göppingen.csv"

df = pd.read_csv(file, sep=',')

df['FT - Bank1'] = df['STFT - Bank1'] + df['LTFT - Bank1']
df['FT - Bank2'] = df['STFT - Bank2'] + df['LTFT - Bank2']

data = [ #'session', \
         #'time', \
         #'GPS Longitude', \
         #'GPS Latitude', \
         #'GPS Bearing', \
         #'Absolute throttle position B', \
         #'Throttle position', \
         #'Fuel Rail Pressure', \
         #'MAF(air flow)', \
         #'Catalyst Temp - Bank 1  Sensor 1', \
         #'Catalyst Temp - Bank 2  Sensor 1', \
         #'STFT - Bank1', \
         #'LTFT - Bank1', \
         'FT - Bank1', \
         #'STFT - Bank2', \
         #'LTFT - Bank2', \
         'FT - Bank2', \
         #'Air Fuel Ratio (alt)', \
         #'Air Fuel Ratio', \
         #'Coolant', \
         'Engine Load', \
         #'Absolute load value', \
         'O2 S1 Equiv. Ratio and/or Current', \
         'O2 Sensor 1x2', \
         'O2 Sensor 2x2', \
         #'Relative throttle position', \
         'RPM', \
         'Timing advance', \
         #'GPS Speed' \
         ]

plotList(data, df)
# Out:
# <div>                            <div id="177ad6f7-15a6-466a-b788-5bba5b558f3a" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("177ad6f7-15a6-466a-b788-5bba5b558f3a")) {                    Plotly.newPlot(                        "177ad6f7-15a6-466a-b788-5bba5b558f3a",                        [{"type": "scattergl", "x": [0.0, 2.57, 3.569, 4.57, 5.57, 6.57, 7.569, 8.569, 10.569, 11.57, 12.569, 13.569, 14.569, 15.57, 16.569, 28.63, 31.63, 32.631, 33.63, 34.63, 35.631, 36.631, 37.631, 38.63, 39.631, 40.631, 41.63, 42.631, 43.631, 44.63, 45.631, 46.63, 47.631, 48.631, 49.63, 50.631, 51.63, 52.63, 53.631, 54.63, 55.63, 56.63, 57.63, 58.631, 59.63, 60.63, 61.63, 62.631, 63.631, 64.631, 65.63, 66.632, 68.631, 69.631, 70.63, 71.63, 72.631, 73.63, 74.63, 75.63
# ...

# %%
from datetime import datetime, timedelta

# utc = 1980-01-06UTC + (gps - (leap_count(2014) - leap_count(1980)))
utc = datetime(1980, 1, 6) + timedelta(seconds=1092121243.0 - (35 - 19))
print(utc)
